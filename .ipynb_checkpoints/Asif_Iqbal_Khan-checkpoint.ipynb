# %% [markdown]
# # ----------Classification using CNN----------

# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#tf.keras.utils.image_dataset_from_directory?

# %%
data = tf.keras.utils.image_dataset_from_directory('data', 
                                                   class_names=["buildings","forest","glacier","mountain","sea","street"],
                                                   image_size=(150,150))
test = tf.keras.utils.image_dataset_from_directory('test', 
                                                   class_names=["buildings","forest","glacier","mountain","sea","street"],
                                                   image_size=(150,150))
# Out:
# Found 14034 files belonging to 6 classes.
# Found 3000 files belonging to 6 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names=["buildings","forest","glacier","mountain","sea","street"]

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(class_names[batch[1][idx]])

# %% [markdown]
# # Scale Data

# %%
test = test.map(lambda x,y: (x/255, y))

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
#data.as_numpy_iterator().next()

# %% [markdown]
# #  Split Data

# %%
test_size = int(len(test))
train_size = int(len(data)*.8)
val_size = int(len(data)*.2)

# %%
train_size
# Out:
# 351

# %%
test_size
# Out:
# 94

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)

# %% [markdown]
# # Build Deep Learning Model

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()
model.add(Conv2D(input_shape=(150,150,3),filters = 32,kernel_size=(3,3),padding = 'same',activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 64,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 64,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 128,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 128,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 256,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(filters= 256,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(150, activation='relu'))
model.add(Dense(6, activation='softmax'))

# %%
model.compile('adam', loss=tf.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 37, 37, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 9, 9, 128)         147584
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 256)         295168
#
#  max_pooling2d_12 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 2, 2, 256)         590080
#
#  max_pooling2d_13 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 150)               38550
#
#  dense_3 (Dense)             (None, 6)                 906
#
# =================================================================
# Total params: 1,202,464
# Trainable params: 1,202,464
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
hist = model.fit(train, epochs=10, validation_data=val)
# Out:
# Epoch 1/10
# 351/351 [==============================] - 35s 98ms/step - loss: 1.1313 - accuracy: 0.5288 - val_loss: 0.9382 - val_accuracy: 0.6056
# Epoch 2/10
# 351/351 [==============================] - 34s 98ms/step - loss: 0.7794 - accuracy: 0.6951 - val_loss: 0.7452 - val_accuracy: 0.7094
# Epoch 3/10
# 351/351 [==============================] - 33s 94ms/step - loss: 0.6190 - accuracy: 0.7735 - val_loss: 0.5898 - val_accuracy: 0.7759
# Epoch 4/10
# 351/351 [==============================] - 33s 93ms/step - loss: 0.4985 - accuracy: 0.8225 - val_loss: 0.5420 - val_accuracy: 0.8003
# Epoch 5/10
# 351/351 [==============================] - 33s 94ms/step - loss: 0.4434 - accuracy: 0.8411 - val_loss: 0.4757 - val_accuracy: 0.8182
# Epoch 6/10
# 351/351 [==============================] - 33s 93ms/step - loss: 0.3859 - accuracy: 0.8592 - val_loss: 0.5458 - val_accuracy: 0.8064
# Epoch 7/10
# 351/351 [==============================] - 33s 93ms/step - loss: 0.3212 - accuracy: 0.8868 - val_loss: 0.5208 - val_accuracy: 0.8168
# Epoch 8/10
# 351/351 [==============================] - 33s 93ms/step - loss: 0.2749 - accuracy: 0.9025 - val_loss: 0.5396 - val_accuracy: 0.8182
# Epoch 9/10
# 351/351 [==============================] - 33s 94ms/step - loss: 0.2377 - accuracy: 0.9145 - val_loss: 0.7358 - val_accuracy: 0.7802
# Epoch 10/10
# 351/351 [==============================] - 34s 96ms/step - loss: 0.2277 - accuracy: 0.9197 - val_loss: 0.5670 - val_accuracy: 0.8416

# %% [markdown]
# # Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
test_loss, test_acc = model.evaluate(test)
# Out:
# 94/94 [==============================] - 3s 29ms/step - loss: 0.6039 - accuracy: 0.8293

# %%
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay

# %%
true_labels = []
predicted_labels = []

for batch in test.as_numpy_iterator(): 
    batch_data, batch_labels = batch
    # Make predictions on the batch
    predictions = model.predict(batch_data)
    
    # Convert predicted labels to integers
    batch_predicted_labels = np.argmax(predictions, axis=1)
    
    # Append true and predicted labels to the respective lists
    true_labels.extend(batch_labels)
    predicted_labels.extend(batch_predicted_labels)
# Out:
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 229ms/step

# %%
confusion = confusion_matrix(true_labels, predicted_labels)
print(confusion)
# Out:
# [[355   3   4   5  16  54]
#  [  4 445   4   4   2  15]
#  [  3   2 400  93  49   6]
#  [  4   0  54 432  34   1]
#  [  9   2  26  33 433   7]
#  [ 64   1   3   3   7 423]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)

# %%
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       437
#            1       0.98      0.94      0.96       474
#            2       0.81      0.72      0.77       553
#            3       0.76      0.82      0.79       525
#            4       0.80      0.85      0.82       510
#            5       0.84      0.84      0.84       501
#
#     accuracy                           0.83      3000
#    macro avg       0.83      0.83      0.83      3000
# weighted avg       0.83      0.83      0.83      3000

# %% [markdown]
# # Test

# %%
test_iterator = test.as_numpy_iterator()
test_batch = test_iterator.next()
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(test_batch[0][:5]):
    ax[idx].imshow(img.astype(int))
    resize = tf.image.resize(img, (150,150))
    prediction = model.predict(np.expand_dims(resize/255, 0))
    predicted_lable = int(prediction.argmax(axis=1))
    ax[idx].title.set_text(class_names[predicted_lable])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# # ----------SVM Classification----------

# %% [markdown]
# ## Loading Training DATA

# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay
Categories=["buildings","forest","glacier","mountain","sea","street"]
flat_data_arr=[] #input array
target_arr=[] #output array
datadir='Data' 
#path which contains all the categories of images
for i in Categories:
    
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(64,64,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(Categories.index(i))
    print(f'loaded category:{i} successfully')
flat_data=np.array(flat_data_arr)
target=np.array(target_arr)
df=pd.DataFrame(flat_data) #dataframe
df['Target']=target
x=df.iloc[:,:-1] #input data 
y=df.iloc[:,-1]#output data
# Out:
# loading... category : buildings
# loaded category:buildings successfully
# loading... category : forest
# loaded category:forest successfully
# loading... category : glacier
# loaded category:glacier successfully
# loading... category : mountain
# loaded category:mountain successfully
# loading... category : sea
# loaded category:sea successfully
# loading... category : street
# loaded category:street successfully

# %% [markdown]
# ## Apply PCA in Train Data

# %%
pca = PCA(n_components=0.9)
X_train = pca.fit_transform(x)

# %%
X_train.shape
# Out:
# (14034, 282)

# %% [markdown]
# # Testing DATA load and Transform

# %%
Categories=["buildings","forest","glacier","mountain","sea","street"]
flat_data_arr=[] #input array
target_arr=[] #output array
datadir='test' 
#path which contains all the categories of images
for i in Categories:
    
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(64,64,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(Categories.index(i))
    print(f'loaded category:{i} successfully')
flat_data=np.array(flat_data_arr)
target=np.array(target_arr)
df_Test=pd.DataFrame(flat_data) #dataframe
df_Test['Target']=target
x_Test=df_Test.iloc[:,:-1] #input data 
y_Test=df_Test.iloc[:,-1]#output data
# Out:
# loading... category : buildings
# loaded category:buildings successfully
# loading... category : forest
# loaded category:forest successfully
# loading... category : glacier
# loaded category:glacier successfully
# loading... category : mountain
# loaded category:mountain successfully
# loading... category : sea
# loaded category:sea successfully
# loading... category : street
# loaded category:street successfully

# %%
x_Test.shape
# Out:
# (3000, 12288)

# %%
x_Test_reduce=pca.transform(x_Test)

# %%
x_Test_reduce.shape
# Out:
# (3000, 282)

# %% [markdown]
# ## Model Training

# %%
classifier = SVC()
classifier.fit(X_train,y)
# Out:
# SVC()

# %% [markdown]
# ## Model Evaluation

# %%
ypredTest = classifier.predict(x_Test_reduce)

# %%
from sklearn.metrics import accuracy_score
SVMaccuracy = accuracy_score(y_Test,ypredTest)

# %%
SVMaccuracy
# Out:
# 0.6486666666666666

# %%
print(classification_report(y_Test,ypredTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.52      0.55       437
#            1       0.77      0.82      0.80       474
#            2       0.63      0.68      0.65       553
#            3       0.62      0.67      0.65       525
#            4       0.61      0.46      0.53       510
#            5       0.66      0.73      0.69       501
#
#     accuracy                           0.65      3000
#    macro avg       0.65      0.65      0.64      3000
# weighted avg       0.65      0.65      0.64      3000

# %%
confusion = confusion_matrix(y_Test,ypredTest)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=Categories)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)

# %% [markdown]
# # Comparision CNN vs SVM

# %%
classifiers=["CNN","SVM"]
acc = [test_acc,SVMaccuracy]
plt.bar(classifiers, acc,width=0.5,color="green")

# Add labels and title
plt.xlabel('classifiers')
plt.ylabel('Accuracy')
plt.title('CNN VS SVM')
plt.show()
